# %%
import dataset_utils

# %%
# dataset_utils.plot_roc_from_file("combo_out_NN_3.txt", "Combination Treatment (3 nodes)")

# %%
# dataset_utils.plot_roc_from_file("multi_combo_out_NN_3.txt", "Multi-Task Combination Treatment (3 nodes)")

# %%
# dataset_utils.plot_roc_from_file("lap_out_NN_3.txt", "Lapatinib Treatment (3 nodes)")

# %%
# dataset_utils.plot_roc_from_file("multi_lap_out_NN_3.txt", "Multi-Task Lapatinib Treatment (3 nodes)")

# %%
# dataset_utils.plot_roc_from_file("trast_out_NN_3.txt", "Trastuzumab Treatment (3 nodes)")

# %%
# dataset_utils.plot_roc_from_file("multi_trast_out_NN_3.txt", "Multi-Task Trastuzumab Treatment (3 nodes)")

# %%
dataset_utils.plot_roc_from_file("multi_combo_out_NN.txt", "Multi-Task Combination Treatment (1 node)")

# %%
dataset_utils.plot_roc_from_file("multi_lap_out_NN.txt", "Multi-Task Lapatinib Treatment (1 node)")

# %%
dataset_utils.plot_roc_from_file("multi_trast_out_NN.txt", "Multi-Task Trastuzumab Treatment (1 node)")

# %%
dataset_utils.plot_roc_from_file("multi_cl_lap_NN.txt", "Multi-Task Lapatinib Cell-Line Treatment (1 node)")
